# %% [markdown]
# #### Required Packages for Demonstration of Descriptive statistics

# %%
import pandas as pd
import numpy as np
from scipy.stats import *

# %% [markdown]
# #### 1. What is the difference between mean, median, and mode?
# #### Real-World Example
#     In a company's employee salary data:
#
#     Mean: Average salary.
#     Median: Middle salary, robust to outliers.
#     Mode: Most frequently occurring salary.
#     Insight: Outliers (8000 repeated) pull the mean up, while the median reflects a better central tendency for skewed data.

# %%
# Example: Salaries of employees
salaries = [3000, 3500, 4000, 4500, 5000, 8000, 8000, 8000]

# Mean
mean = np.mean(salaries)

# Median
median = np.median(salaries)

# Mode
mode = stats.mode(salaries)

print(f"Mean Salary: {mean}")
print(f"Median Salary: {median}")
print(f"Mode Salary: {mode.mode} (Count: {mode.count})")
# Out:
# Mean Salary: 5500.0
# Median Salary: 4750.0
# Mode Salary: 8000 (Count: 3)

# %% [markdown]
# #### 2. If a dataset has outliers, which measure of central tendency would you use and why?
#     Real-World Example
#     For house prices, a few mansions can skew the average (mean), so median is used to get a fair central value.
#     Insight: Median is more robust to outliers and gives a better representation of typical house prices.

# %%
house_prices = [100000, 150000, 200000, 250000, 1000000]  # Outlier present

mean_price = np.mean(house_prices)
median_price = np.median(house_prices)

print(f"Mean House Price: {mean_price}")
print(f"Median House Price: {median_price}")
# Out:
# Mean House Price: 340000.0
# Median House Price: 200000.0

# %% [markdown]
# #### 3. What does standard deviation tell you about a dataset?
#     Real-World Example
#     In stock prices, a high standard deviation means the prices are volatile, while a low standard deviation means prices are stable.
#     Insight: Lower standard deviation indicates more stability in prices.

# %%
# Two stock price datasets
stable_stock = [100, 101, 100, 102, 101]
volatile_stock = [100, 110, 90, 115, 85]

# Calculate standard deviation
stable_std = np.std(stable_stock)
volatile_std = np.std(volatile_stock)

print(f"Standard Deviation of Stable Stock: {stable_std:.2f}")
print(f"Standard Deviation of Volatile Stock: {volatile_std:.2f}")
# Out:
# Standard Deviation of Stable Stock: 0.75
# Standard Deviation of Volatile Stock: 11.40

# %% [markdown]
# #### 4. How do you calculate the range of a dataset?
#     Real-World Example
#     Temperature fluctuations over a week: the range tells the difference between the highest and lowest temperatures.
#     Insight: Range gives a quick idea of variability in the dataset.

# %%
temperatures = [20, 22, 24, 25, 30, 32, 35]  # Temperature values in Celsius

# Calculate range
range_temp = max(temperatures) - min(temperatures)

print(f"Temperature Range: {range_temp}°C")
# Out:
# Temperature Range: 15°C

# %% [markdown]
# #### 5. What is the difference between population and sample variance?
#     Real-World Example
#     Population variance: When analyzing the entire population (e.g., all student grades in a school).
#     Sample variance: When analyzing a sample (e.g., grades of a classroom).
#     Insight:
#     Population variance uses 𝑁 and N as denominator.
#     Sample variance uses 𝑁−1 . N−1 to correct bias in small samples.

# %%
# Population data
population_data = [2, 4, 4, 4, 5, 5, 7, 9]

# Sample data (subset of population)
sample_data = [2, 4, 4, 5]

# Population Variance
population_variance = np.var(population_data)

# Sample Variance (ddof=1 for unbiased estimator)
sample_variance = np.var(sample_data, ddof=1)

print(f"Population Variance: {population_variance:.2f}")
print(f"Sample Variance: {sample_variance:.2f}")
# Out:
# Population Variance: 4.00
# Sample Variance: 1.58

# %% [markdown]
# #### 6. When the mean, median, and mode are approximately equal, what type of distribution is it?
#     Real-World Example
#     Heights of adults typically follow a normal distribution, where mean ≈ median ≈ mode.

# %% [markdown]
# #### Insight: This is a hallmark of a normal distribution.
#     Normal Distribution and Mean, Median, Mode
#     In a perfect normal distribution:
#
#     Mean = Median = Mode
#     This happens because the data is symmetrical and evenly distributed around the center.
#     However, in real-world datasets or simulated data, we might observe:
#
#     Mean ≈ Median but Mode differs slightly.
#     Why Does Mode Differ?
#     Nature of Mode:
#
#     The mode represents the most frequently occurring value in a dataset.
#     In continuous data (like a normal distribution), values are usually not repeated. As a result, the mode can differ slightly or may not exist as a single unique value.
#     Sampling Noise:
#
#     When simulating or sampling data from a normal distribution, there might be small deviations due to randomness.
#     The mode can appear slightly different because it depends on the most frequent value within the sampled data, not the theoretical center of the distribution.

# %%
import matplotlib.pyplot as plt

# Normally distributed data
data = np.random.normal(50, 10, 1000)  # mean=50, std=10

# Calculate mean, median, mode
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)

print(f"Mean: {mean:.2f}")
print(f"Median: {median:.2f}")
print(f"Mode: {mode.mode:.2f}")

# Visualize the distribution
plt.hist(data, bins=30, color='lightblue', edgecolor='black')
plt.title("Normal Distribution")
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1, label="Mean")
plt.axvline(median, color='green', linestyle='dashed', linewidth=1, label="Median")
plt.legend()
plt.show()
# Out:
# Mean: 50.33
# Median: 50.49
# Mode: 19.18

# %% [markdown]
# #### 7. What does it mean if a dataset has a standard deviation of 0?
#     Real-World Example
#     If all machines in a factory produce parts of exactly the same size, the standard deviation is 0.
#     Insight: All values are identical; there is no variability.

# %%
data = [5, 5, 5, 5, 5]

# Standard deviation
std_dev = np.std(data)

print(f"Standard Deviation: {std_dev}")
# Out:
# Standard Deviation: 0.0

# %% [markdown]
# #### 8. How is skewness related to mean and median?
#     Real-World Example
#     In income data:
#
#     If mean > median, the data is right-skewed due to a few high incomes.
#     If mean < median, the data is left-skewed.

# %%
# Right-skewed data
data = [1, 2, 2, 3, 3, 4, 10]

mean = np.mean(data)
median = np.median(data)

print(f"Mean: {mean}")
print(f"Median: {median}")

if mean > median:
    print("The data is Right-Skewed.")
elif mean < median:
    print("The data is Left-Skewed.")
else:
    print("The data is Symmetrical.")
# Out:
# Mean: 3.5714285714285716
# Median: 3.0
# The data is Right-Skewed.

# %% [markdown]
# #### 9. What are Q1, Q2 (Median), and Q3?
#     Real-World Example
#     In exam scores, quartiles help segment students into groups (e.g., top 25%).

# %%
data = [10, 20, 30, 40, 50, 60, 70, 80]

Q1 = np.percentile(data, 25)
Q2 = np.percentile(data, 50)
Q3 = np.percentile(data, 75)

print(f"Q1 (25th Percentile): {Q1}")
print(f"Q2 (Median): {Q2}")
print(f"Q3 (75th Percentile): {Q3}")
# Out:
# Q1 (25th Percentile): 27.5
# Q2 (Median): 45.0
# Q3 (75th Percentile): 62.5

# %% [markdown]
# #### What is the purpose of a boxplot in descriptive statistics?
#     Visualize the Distribution of Data:
#     A boxplot gives a quick snapshot of how the data is distributed (e.g., symmetrical, skewed, or with outliers).
#
#     Identify Outliers:
#     Boxplots highlight data points that fall outside the typical range using "whiskers" and dots.
#
#     Understand Variability:
#     By showing the Interquartile Range (IQR), a boxplot gives an idea of the data's spread.
#
#     Compare Multiple Distributions:
#     Boxplots make it easy to compare multiple datasets side by side.
#
#     Display Five-Number Summary:
#     A boxplot displays the five key statistical measures:
#
#     Minimum (excluding outliers)
#     First Quartile (Q1)
#     Median (Q2)
#     Third Quartile (Q3)
#     Maximum (excluding outliers)

# %% [markdown]
# #### Insights from the Boxplot:
#     If Department A has an outlier (e.g., $10,000), it will appear as a dot beyond the whiskers.
#     Department B might have a tighter box, indicating low variability in salaries.

# %% [markdown]
# #### Output Interpretation
#     Box: The box shows the Interquartile Range (IQR), which represents the middle 50% of data.
#     Line inside the Box: The median (Q2) value.
#     Whiskers: Lines extending from the box indicate the range within 1.5 times the IQR.
#     Dots: Outliers that fall outside the whiskers.

# %%
import matplotlib.pyplot as plt

# Example salary data
department_A = [3000, 3200, 3500, 3700, 4000, 4100, 5000, 10000]  # Outlier (10000)
department_B = [3100, 3300, 3400, 3600, 3800, 3900, 4000]

# Create the boxplot
plt.boxplot([department_A, department_B], labels=["Department A", "Department B"])
plt.title("Salary Distribution in Departments A and B")
plt.ylabel("Salary")
plt.grid(True)
plt.show()
# Out:
# /var/folders/1d/bjjvkwbs1z9g3qyx5vpjhsdc0000gn/T/ipykernel_99508/2130548837.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([department_A, department_B], labels=["Department A", "Department B"])

# %% [markdown]
# #### MEDIUM LEVEL QUESTIONS

# %% [markdown]
# #### 1. If a dataset has a mean of 50 and a standard deviation of 10, what does that tell you about the data's spread?
#     Real-World Explanation:
#     In a dataset of students' scores:
#
#     Mean = 50: The average score is 50.
#     Standard Deviation = 10: Scores are, on average, 10 points away from the mean.
#     If the data follows a normal distribution:
#
#     ~68% of scores fall between 40 (50-10) and 60 (50+10).

# %%
mean = 50
std_dev = 10

# Generate data with a normal distribution
data = np.random.normal(mean, std_dev, 1000)

# Plot the distribution
plt.hist(data, bins=30, color='lightblue', edgecolor='black', density=True)
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1, label="Mean")
plt.axvline(mean - std_dev, color='green', linestyle='dashed', linewidth=1, label="1 Std Dev Below")
plt.axvline(mean + std_dev, color='green', linestyle='dashed', linewidth=1, label="1 Std Dev Above")
plt.title("Normal Distribution of Scores")
plt.legend()
plt.show()

# %% [markdown]
# #### 2. How do you interpret a histogram with a right-skewed distribution?
#     Real-World Explanation:
#     In income distribution:
#
#     Most people earn average incomes (left side of the histogram).
#     A few individuals with high incomes pull the mean to the right, causing a right-skewed distribution.
#     Insight: The tail on the right indicates a few very large values (outliers).

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulate right-skewed data
data = np.random.exponential(scale=2, size=1000)

# Plot histogram
plt.hist(data, bins=30, color='lightblue', edgecolor='black')
plt.title("Right-Skewed Distribution")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### 3. What is the importance of variance, and how is it different from standard deviation?
#     Real-World Explanation:
#     Variance measures the spread of data around the mean but is expressed in squared units.
#     Standard Deviation is the square root of variance and is in the same units as the data, making it more interpretable.
#     Insight: Standard deviation is easier to interpret because it’s in the same units as the data.

# %%
data = [10, 12, 15, 18, 20, 25, 30]

# Variance
variance = np.var(data)

# Standard Deviation
std_dev = np.sqrt(variance)

print(f"Variance: {variance:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")
# Out:
# Variance: 43.39
# Standard Deviation: 6.59

# %% [markdown]
# #### 4. How do you interpret the IQR (Interquartile Range), and how is it used to detect outliers?
#     Real-World Explanation:
#     The IQR measures the spread of the middle 50% of the data:
#
#     Outliers are values that lie beyond
#     Q1−1.5×IQR or Q3+1.5×IQR.
#     Insight: IQR is robust to extreme values, and outliers can be identified easily.

# %%
data = [10, 12, 15, 18, 20, 22, 25, 30, 100]  # Outlier present

# Calculate Q1, Q3, and IQR
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

# Calculate bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = [x for x in data if x < lower_bound or x > upper_bound]

print(f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
print(f"Outliers: {outliers}")
# Out:
# Q1: 15.0, Q3: 25.0, IQR: 10.0
# Outliers: [100]

# %% [markdown]
# #### 5. You are given two datasets with the same mean but different standard deviations. What can you conclude?
#     Real-World Explanation:
#     If two exam groups have the same mean score:
#
#     Group A (low std dev): Scores are tightly clustered around the mean.
#     Group B (high std dev): Scores are more spread out.
#     Insight: The spread of Group B (higher std dev) is much wider compared to Group A

# %%
import matplotlib.pyplot as plt

# Two datasets with the same mean but different std deviations
group_A = np.random.normal(50, 5, 1000)  # Low std dev
group_B = np.random.normal(50, 15, 1000) # High std dev

plt.hist(group_A, bins=30, alpha=0.5, label="Group A (Low Std Dev)")
plt.hist(group_B, bins=30, alpha=0.5, label="Group B (High Std Dev)")
plt.title("Comparison of Two Datasets with Same Mean")
plt.legend()
plt.show()

# %% [markdown]
# #### 6. What do you infer if the skewness of a dataset is -1.5?
#     Real-World Explanation:
#     A skewness of -1.5 indicates a left-skewed (negative skew) distribution, where:
#
#     The mean is pulled to the left (towards smaller values).
#     Example: Exam scores with a few very low scores.

# %%
from scipy.stats import skew

data = [1, 1, 0, 0, 1, 1, 0, 2, 3, 0]  # Left-skewed dataset

# Calculate skewness
skewness = skew(data)

print(f"Skewness: {skewness:.2f}")
if skewness < 0:
    print("The data is Left-Skewed (Negative Skew).")
# Out:
# Skewness: 0.91

# %% [markdown]
# #### 7. How do you create a frequency table, and why is it useful?
#     Real-World Explanation:
#     A frequency table helps organize data into groups to understand its distribution.
#     For example, in a survey, a frequency table can summarize age groups.
#
#     Insight: The table shows how many times each age appears in the dataset.

# %%
import pandas as pd

# Example data: Ages of survey participants
ages = [18, 21, 22, 25, 25, 30, 30, 30, 35, 40]

# Create a frequency table
frequency_table = pd.Series(ages).value_counts().sort_index()

print("Frequency Table:")
print(frequency_table)
# Out:
# Frequency Table:
# 18    1
# 21    1
# 22    1
# 25    2
# 30    3
# 35    1
# 40    1
# Name: count, dtype: int64

# %% [markdown]
# #### 8.How would you compare two datasets using measures of central tendency and dispersion?
#     Real-World Example: Comparing Salaries of Two Departments
#     Suppose you have the monthly salaries of employees in two departments:
#
#     Department A has high variability (more spread).
#     Department B is more consistent (less spread).
#     We compare:
#
#     Mean/Median to check central tendency (average salary).
#     Standard Deviation and IQR to analyze how spread out the salaries are.
# Insight :
#     When comparing two datasets:
#
#     Use central tendency (mean, median) to understand where the data is centered.
#     Use dispersion (standard deviation, IQR) to measure variability.
#     Visualize with boxplots or histograms for intuitive comparison.

# %%
# Salaries of employees in two departments
department_A = [3000, 3200, 3500, 4000, 4100, 5000, 7000, 12000]  # High spread
department_B = [3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200]   # Low spread

# Calculate central tendency
mean_A, median_A = np.mean(department_A), np.median(department_A)
mean_B, median_B = np.mean(department_B), np.median(department_B)

# Calculate dispersion
std_A, iqr_A = np.std(department_A), np.percentile(department_A, 75) - np.percentile(department_A, 25)
std_B, iqr_B = np.std(department_B), np.percentile(department_B, 75) - np.percentile(department_B, 25)

# Print comparisons
print("Department A:")
print(f"Mean: {mean_A:.2f}, Median: {median_A}, Std Dev: {std_A:.2f}, IQR: {iqr_A}\n")

print("Department B:")
print(f"Mean: {mean_B:.2f}, Median: {median_B}, Std Dev: {std_B:.2f}, IQR: {iqr_B}")

# Boxplot for Visualization
plt.boxplot([department_A, department_B], labels=["Department A", "Department B"])
plt.title("Salary Comparison: Department A vs. Department B")
plt.ylabel("Salaries")
plt.grid(True)
plt.show()
# Out:
# Department A:
# Mean: 5225.00, Median: 4050.0, Std Dev: 2826.11, IQR: 2075.0
#
# Department B:
# Mean: 3850.00, Median: 3850.0, Std Dev: 229.13, IQR: 350.0
# /var/folders/1d/bjjvkwbs1z9g3qyx5vpjhsdc0000gn/T/ipykernel_99508/211177200.py:21: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([department_A, department_B], labels=["Department A", "Department B"])

# %% [markdown]
# #### HARD QUESTIONS

# %% [markdown]
# #### 1. Explain the difference between univariate, bivariate, and multivariate analysis with examples.
#     Real-World Explanation:
#     Univariate Analysis: Analyzing a single variable (e.g., average salary of employees).
#     Bivariate Analysis: Analyzing two variables to study their relationship (e.g., salary vs. experience).
#     Multivariate Analysis: Analyzing multiple variables simultaneously (e.g., salary, experience, and age).

# %%
# Example data: Salaries, Experience, and Age
data = {
    "Salary": [3000, 3500, 4000, 4500, 5000, 7000, 8000],
    "Experience": [1, 2, 3, 4, 5, 6, 7],
    "Age": [22, 24, 27, 29, 32, 35, 40],
}

df = pd.DataFrame(data)

# Univariate Analysis: Salary
print("Univariate Analysis - Descriptive Statistics for Salary:")
print(df['Salary'].describe())

# Bivariate Analysis: Salary vs. Experience
plt.scatter(df['Experience'], df['Salary'])
plt.title("Bivariate Analysis: Salary vs. Experience")
plt.xlabel("Experience (Years)")
plt.ylabel("Salary")
plt.show()

# Multivariate Analysis: Correlation Matrix
print("Multivariate Analysis - Correlation Matrix:")
print(df.corr())
# Out:
# Univariate Analysis - Descriptive Statistics for Salary:
# count       7.000000
# mean     5000.000000
# std      1848.422751
# min      3000.000000
# 25%      3750.000000
# 50%      4500.000000
# 75%      6000.000000
# max      8000.000000
# Name: Salary, dtype: float64
# Multivariate Analysis - Correlation Matrix:
#               Salary  Experience       Age
# Salary      1.000000    0.960001  0.978914
# Experience  0.960001    1.000000  0.990460
# Age         0.978914    0.990460  1.000000

# %% [markdown]
# #### 2. A dataset has extreme positive outliers. How would you handle the skewness while analyzing the central tendency?
#     Real-World Explanation:
#     When extreme positive outliers are present:
#
#     Median is preferred over the mean because it is not affected by outliers.
#     You can apply transformations (e.g., log transformation) to reduce skewness.

# %%
# Dataset with positive outliers
data = [10, 12, 15, 18, 20, 25, 1000]  # Extreme outlier: 1000

# Calculate Mean and Median
mean = np.mean(data)
median = np.median(data)

print(f"Mean: {mean:.2f}")
print(f"Median: {median}")

# Log Transformation
log_data = np.log(data)

# Plot original vs. transformed data
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(data, bins=10, color="lightblue", edgecolor="black")
plt.title("Original Data")

plt.subplot(1, 2, 2)
plt.hist(log_data, bins=10, color="lightgreen", edgecolor="black")
plt.title("Log-Transformed Data")
plt.show()
# Out:
# Mean: 157.14
# Median: 18.0

# %% [markdown]
# #### 3. Given a boxplot with an IQR of 10, how would you calculate the range of potential outliers?
#     Real-World Explanation:
#     For a given IQR = 10, outliers lie outside:
#     Lower Bound=Q1−1.5×IQR,Upper Bound=Q3+1.5×IQR
#     Insight: Any data point below 5 or above 45 is considered an outlier.

# %%
# Example values
Q1 = 20
Q3 = 30
IQR = Q3 - Q1  # IQR = 10

# Calculate bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound for Outliers: {lower_bound}")
print(f"Upper Bound for Outliers: {upper_bound}")
# Out:
# Lower Bound for Outliers: 5.0
# Upper Bound for Outliers: 45.0

# %% [markdown]
# #### 4. Explain the concept of a weighted mean with a real-world example.
#     Real-World Explanation:
#     In school grading systems, certain subjects (e.g., Mathematics) may carry more weight than others. A weighted mean gives more importance to specific values.
#     Insight: Math (highest weight) significantly influences the final score.

# %%
import numpy as np

# Marks and their weights
marks = [85, 90, 78]  # Math, Science, English
weights = [0.5, 0.3, 0.2]  # Weights assigned to each subject

# Calculate Weighted Mean
weighted_mean = np.average(marks, weights=weights)

print(f"Weighted Mean: {weighted_mean:.2f}")
# Out:
# Weighted Mean: 85.10

# %% [markdown]
# #### 5. What is the empirical rule (68-95-99.7 rule), and how does it relate to a normal distribution?
#     Real-World Explanation:
#     The Empirical Rule states that for a normal distribution:
#
#     ~68% of data lies within 1 standard deviation of the mean.
#     ~95% within 2 standard deviations.
#     ~99.7% within 3 standard deviations.
#     This rule helps to quickly estimate data spread.

# %% [markdown]
# #### Output and Interpretation:
#     ~68% of data falls between μ−σ and μ+σ.
#     ~95% falls between μ−2σ and μ+2σ.
#     ~99.7% falls between μ−3σ and μ+3σ.
#     This confirms the empirical rule.

# %%
# Simulate normally distributed data
mean, std_dev = 50, 10
data = np.random.normal(mean, std_dev, 10000)

# Plot the histogram
plt.hist(data, bins=50, color="lightblue", edgecolor="black", density=True)
plt.title("Normal Distribution and Empirical Rule")
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1, label="Mean")
plt.axvline(mean - std_dev, color='green', linestyle='dashed', label="1 Std Dev")
plt.axvline(mean + std_dev, color='green', linestyle='dashed')
plt.axvline(mean - 2*std_dev, color='orange', linestyle='dashed', label="2 Std Dev")
plt.axvline(mean + 2*std_dev, color='orange', linestyle='dashed')
plt.axvline(mean - 3*std_dev, color='blue', linestyle='dashed', label="3 Std Dev")
plt.axvline(mean + 3*std_dev, color='blue', linestyle='dashed')
plt.legend()
plt.show()

# %% [markdown]
# #### 6.What is Kurtosis and How to Interpret It?
#     Kurtosis is a statistical measure that describes the shape of the tails in a data distribution, particularly focusing on:
#
#     How heavy or light the tails are compared to a normal distribution.
#     Whether extreme values (outliers) are likely in the dataset.

# %% [markdown]
# #### Types of Kurtosis
#     Mesokurtic (Normal Distribution):
#
#     Kurtosis ≈ 3 (Excess Kurtosis ≈ 0).
#     Tails are similar to a normal distribution.
#
#     Leptokurtic (Heavy-Tailed):
#
#     Kurtosis > 3 (Excess Kurtosis > 0).
#     The distribution has heavier tails and a sharper peak.
#     Interpretation: Higher likelihood of extreme values (outliers).
#     Example: Financial returns where extreme gains or losses occur.
#
#     Platykurtic (Light-Tailed):
#
#     Kurtosis < 3 (Excess Kurtosis < 0).
#     The distribution has lighter tails and a flatter peak.
#     Interpretation: Fewer extreme values compared to normal distribution.
#     Example: Test scores where most students score near the mean.

# %% [markdown]
# #### Real-World Example
#     Stock Market Returns:
#     Leptokurtic distributions indicate higher chances of extreme price changes.
#     Quality Control:
#     In manufacturing, platykurtic distributions suggest consistent product measurements with fewer outliers.

# %% [markdown]
# #### Key Insight
#     High kurtosis → Be cautious of outliers and extreme values.
#     Low kurtosis → The data is stable, with fewer extreme observations.

# %%
from scipy.stats import kurtosis

# Generate three distributions
normal_data = np.random.normal(0, 1, 1000)  # Mesokurtic
heavy_tailed_data = np.random.laplace(0, 1, 1000)  # Leptokurtic
light_tailed_data = np.random.uniform(-1, 1, 1000)  # Platykurtic

# Calculate kurtosis
kurt_normal = kurtosis(normal_data)
kurt_heavy = kurtosis(heavy_tailed_data)
kurt_light = kurtosis(light_tailed_data)

# Print kurtosis values
print(f"Normal Distribution Kurtosis: {kurt_normal:.2f} (Mesokurtic)")
print(f"Heavy-Tailed Distribution Kurtosis: {kurt_heavy:.2f} (Leptokurtic)")
print(f"Light-Tailed Distribution Kurtosis: {kurt_light:.2f} (Platykurtic)")

# Plot the distributions
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.hist(normal_data, bins=30, color="lightblue", edgecolor="black")
plt.title("Mesokurtic (Normal Distribution)")

plt.subplot(1, 3, 2)
plt.hist(heavy_tailed_data, bins=30, color="lightgreen", edgecolor="black")
plt.title("Leptokurtic (Heavy-Tailed)")

plt.subplot(1, 3, 3)
plt.hist(light_tailed_data, bins=30, color="lightcoral", edgecolor="black")
plt.title("Platykurtic (Light-Tailed)")

plt.tight_layout()
plt.show()
# Out:
# Normal Distribution Kurtosis: 0.17 (Mesokurtic)
# Heavy-Tailed Distribution Kurtosis: 2.66 (Leptokurtic)
# Light-Tailed Distribution Kurtosis: -1.16 (Platykurtic)

# %% [markdown]
# #### How do you test if two datasets have equal variance (homoscedasticity)?
#     Testing If Two Datasets Have Equal Variance (Homoscedasticity)
#     To test if two datasets have equal variance (homoscedasticity), you can use statistical tests like:
#
#     Levene's Test
#     Bartlett's Test
#     Both tests are used to check the assumption of equal variances, which is crucial for certain statistical tests such as t-tests and ANOVA.

# %% [markdown]
# #### 1. Levene's Test
#     Purpose: Tests the null hypothesis that the variances of two or more datasets are equal.
#     Robustness: It is less sensitive to deviations from normality compared to Bartlett's Test.
#     Steps:
#     If the p-value > 0.05: Fail to reject the null hypothesis → Variances are equal.
#     If the p-value ≤ 0.05: Reject the null hypothesis → Variances are not equal.

# %% [markdown]
# #### Real-World Example: Compare Variance of Two Datasets (Test Scores)
# Suppose you want to check whether the test scores of students from two different classes have equal variances.

# %%
import numpy as np
from scipy.stats import levene

# Test scores for two classes
class_A = [85, 88, 90, 92, 95, 100, 105]
class_B = [70, 75, 80, 85, 90, 95, 100]

# Perform Levene's test
stat, p_value = levene(class_A, class_B)

print(f"Levene's Test Statistic: {stat:.2f}")
print(f"P-Value: {p_value:.3f}")

if p_value > 0.05:
    print("Fail to reject the null hypothesis: Variances are equal (Homoscedasticity).")
else:
    print("Reject the null hypothesis: Variances are not equal (Heteroscedasticity).")
# Out:
# Levene's Test Statistic: 1.51
# P-Value: 0.243
# Fail to reject the null hypothesis: Variances are equal (Homoscedasticity).

# %% [markdown]
# #### 2. Bartlett's Test
#     Purpose: Tests the null hypothesis that the variances of two or more datasets are equal.
#     Robustness: Bartlett’s Test is sensitive to non-normal data.
#     Steps:
#     If the p-value > 0.05: Fail to reject the null hypothesis → Variances are equal.
#     If the p-value ≤ 0.05: Reject the null hypothesis → Variances are not equal.

# %%
from scipy.stats import bartlett

# Perform Bartlett's test
stat, p_value = bartlett(class_A, class_B)

print(f"Bartlett's Test Statistic: {stat:.2f}")
print(f"P-Value: {p_value:.3f}")

if p_value > 0.05:
    print("Fail to reject the null hypothesis: Variances are equal (Homoscedasticity).")
else:
    print("Reject the null hypothesis: Variances are not equal (Heteroscedasticity).")
# Out:
# Bartlett's Test Statistic: 1.01
# P-Value: 0.314
# Fail to reject the null hypothesis: Variances are equal (Homoscedasticity).

# %% [markdown]
# #### When to Use Which Test?
#     Levene's Test: Preferred when data may not follow a normal distribution.
#     Bartlett's Test: Suitable when data is assumed to be normally distributed.

# %% [markdown]
# #### Why Does Equal Variance Matter?
#     Equal variances (homoscedasticity) are an assumption in statistical tests such as:
#
#     t-tests (independent samples).
#     ANOVA (comparing means across multiple groups).
#     If variances are not equal (heteroscedasticity), you should use alternative methods like:
#
#     Welch's t-test instead of a standard t-test.
#     Robust statistical methods.
